# %%
import pandas as pd
df=pd.read_csv('ratings.csv')

# %%
df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
c=df[df['rating']==5]

# %%
c['movieId']
# Out:
# 3             47
# 4             50
# 6            101
# 8            151
# 9            157
#            ...
# 100814    158238
# 100829    164179
# 100832    168248
# 100833    168250
# 100834    168252
# Name: movieId, Length: 13211, dtype: int64

# %%
df1=pd.read_csv('movies.csv')

# %%
df1.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
final=pd.merge(df,df1,on="movieId")

# %%
f=final[final['rating']==5]

# %%
f[f['userId']==296]
# Out:
#        userId  movieId  rating   timestamp  \
# 669       296       50     5.0  1532993858
# 965       296      110     5.0  1532993855
# 2581      296      356     5.0  1532993877
# 14418     296     2959     5.0  1532993828
# 16446     296      318     5.0  1532993816
# 16681     296     1704     5.0  1532993830
# 17525     296    79132     5.0  1532993826
# 22669     296     2324     5.0  1532993836
# 24491     296     4144     5.0  1532994130
# 49017     296     1201     5.0  1532993957
# 92237     296    65261     5.0  1532994005
# 93163     296    31364     5.0  1532993898
#
#                                                    title  \
# 669                           Usual Suspects, The (1995)
# 965                                    Braveheart (1995)
# 2581                                 Forrest Gump (1994)
# 14418                                  Fight Club (1999)
# 16446                   Shawshank Redemption, The (1994)
# ...

# %%
f[f['title'].isin(['Matrix',
'Pulp Fiction',
'Forrest Gump',
'Shawshank Redemption'])]
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating, timestamp, title, genres]
# Index: []

# %%
tag=pd.read_csv('tags.csv')

# %%
tag
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
df1.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
#2571
tag.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
tag[tag['movieId']==2571]
# Out:
#       userId  movieId                 tag   timestamp
# 815      424     2571        martial arts  1457842912
# 816      424     2571              sci-fi  1457842899
# 1646     474     2571  alternate universe  1137204991
# 2794     537     2571          philosophy  1424141098
# 2795     537     2571    post apocalyptic  1424141101

# %%
df1[df1['title']=="Terminator 2: Judgment Day (1991)"]
# Out:
#      movieId                              title         genres
# 507      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi

# %%
final.head()
# Out:
#    userId  movieId  rating   timestamp             title  \
# 0       1        1     4.0   964982703  Toy Story (1995)
# 1       5        1     4.0   847434962  Toy Story (1995)
# 2       7        1     4.5  1106635946  Toy Story (1995)
# 3      15        1     2.5  1510577970  Toy Story (1995)
# 4      17        1     4.5  1305696483  Toy Story (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1  Adventure|Animation|Children|Comedy|Fantasy
# 2  Adventure|Animation|Children|Comedy|Fantasy
# 3  Adventure|Animation|Children|Comedy|Fantasy
# 4  Adventure|Animation|Children|Comedy|Fantasy

# %%
a=final[final['movieId']==589]
a['rating'].mean()
# Out:
# 3.970982142857143

# %%
import matplotlib.pyplot as plt

plt.plot(final[final['title']=="Fight Club (1999)"]['rating'])

# %%
a=pd.DataFrame(final.groupby('movieId')['rating'].mean())
b=pd.merge(a,df1,on='movieId')
c=final.groupby('movieId')['movieId'].count().rename('count')
pd.DataFrame(c)
c=pd.merge(c,b,on="movieId")
c
# Out:
#       movieId  count    rating                                      title  \
# 0           1    215  3.920930                           Toy Story (1995)
# 1           2    110  3.431818                             Jumanji (1995)
# 2           3     52  3.259615                    Grumpier Old Men (1995)
# 3           4      7  2.357143                   Waiting to Exhale (1995)
# 4           5     49  3.071429         Father of the Bride Part II (1995)
# ...       ...    ...       ...                                        ...
# 9719   193581      1  4.000000  Black Butler: Book of the Atlantic (2017)
# 9720   193583      1  3.500000               No Game No Life: Zero (2017)
# 9721   193585      1  3.500000                               Flint (2017)
# 9722   193587      1  3.500000        Bungo Stray Dogs: Dead Apple (2018)
# 9723   193609      1  4.000000        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# ...

# %%
c=c[c['count']>50]
c
# Out:
#       movieId  count    rating                             title  \
# 0           1    215  3.920930                  Toy Story (1995)
# 1           2    110  3.431818                    Jumanji (1995)
# 2           3     52  3.259615           Grumpier Old Men (1995)
# 5           6    102  3.946078                       Heat (1995)
# 6           7     54  3.185185                    Sabrina (1995)
# ...       ...    ...       ...                               ...
# 8287   106782     54  3.916667   Wolf of Wall Street, The (2013)
# 8354   109374     52  3.778846  Grand Budapest Hotel, The (2014)
# 8358   109487     73  3.993151               Interstellar (2014)
# 8457   112852     59  4.050847    Guardians of the Galaxy (2014)
# 8673   122904     54  3.833333                   Deadpool (2016)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# ...

# %%
c.sort_values('count',ascending=False).head(20)
# Out:
#       movieId  count    rating  \
# 314       356    329  4.164134
# 277       318    317  4.429022
# 257       296    307  4.197068
# 510       593    279  4.161290
# 1938     2571    278  4.192446
# 224       260    251  4.231076
# 418       480    238  3.750000
# 97        110    237  4.031646
# 507       589    224  3.970982
# 461       527    220  4.225000
# 2224     2959    218  4.272936
# 0           1    215  3.920930
# 897      1196    211  4.215640
# 46         50    204  4.237745
# 2144     2858    204  4.056373
# 43         47    203  3.975369
# 615       780    202  3.445545
# 123       150    201  3.845771
# 899      1198    200  4.207500
# 3633     4993    198  4.106061
#
#                                                   title  \
# 314                                 Forrest Gump (1994)
# 277                    Shawshank Redemption, The (1994)
# 257                                 Pulp Fiction (1994)
# 510                    Silence of the Lambs, The (1991)
# ...

# %%
links=pd.read_csv('links.csv')
ed=pd.merge(c,links,on="movieId")
ed.sort_values('imdbId',ascending=False)
# Out:
#      movieId  count    rating                                   title  \
# 432   109374     52  3.778846        Grand Budapest Hotel, The (2014)
# 434   112852     59  4.050847          Guardians of the Galaxy (2014)
# 430    99114     71  3.943662                 Django Unchained (2012)
# 426    81845     58  4.043103               King's Speech, The (2010)
# 435   122904     54  3.833333                         Deadpool (2016)
# ..       ...    ...       ...                                     ...
# 123      923     69  4.043478                     Citizen Kane (1941)
# 102      596     60  3.450000                        Pinocchio (1940)
# 171     1282     53  3.783019                         Fantasia (1940)
# 122      919     92  3.880435                Wizard of Oz, The (1939)
# 100      594     77  3.616883  Snow White and the Seven Dwarfs (1937)
#
#                                        genres   imdbId    tmdbId
# ...
